# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df2017CAPE_PW_00Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df1 = pd.read_csv("df2017CAPE_PW_12Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df.CAPE=pd.to_numeric(df.CAPE, errors='coerce')
df1.CAPE=pd.to_numeric(df.CAPE, errors='coerce')

# %%
df.head(10)
# Out:
#          Date  CAPE     PW
# 0  01 01 2017  0.00   5.18
# 1  02 01 2017  0.00   5.95
# 2  03 01 2017  0.00  24.64
# 3  04 01 2017  0.00  10.52
# 4  05 01 2017  0.00   4.02
# 5  06 01 2017  0.19   2.77
# 6  07 01 2017  0.00   1.58
# 7  08 01 2017  0.00   2.16
# 8  09 01 2017  0.00   4.49
# 9  10 01 2017  0.00  11.77

# %%
df1.head(10)
# Out:
#          Date  CAPE     PW
# 0  01 01 2017  0.00   4.44
# 1  02 01 2017  0.00  19.42
# 2  03 01 2017  0.00  22.08
# 3  04 01 2017  0.00   2.55
# 4  05 01 2017  0.00   5.10
# 5  06 01 2017  0.19   1.54
# 6  07 01 2017  0.00   3.29
# 7  08 01 2017  0.00   1.24
# 8  09 01 2017  0.00   6.13
# 9  10 01 2017  0.00  22.70

# %%
df['Ndate'] = pd.to_datetime(df['Date'], format='%d %m %Y')
df['month'] = df['Ndate'].dt.month
df1['Ndate'] = pd.to_datetime(df['Date'], format='%d %m %Y')
df1['month'] = df1['Ndate'].dt.month

# %%
df.head(5)
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   0.0   5.18 2017-01-01      1
# 1  02 01 2017   0.0   5.95 2017-01-02      1
# 2  03 01 2017   0.0  24.64 2017-01-03      1
# 3  04 01 2017   0.0  10.52 2017-01-04      1
# 4  05 01 2017   0.0   4.02 2017-01-05      1

# %%
df1.head(5)
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   0.0   4.44 2017-01-01      1
# 1  02 01 2017   0.0  19.42 2017-01-02      1
# 2  03 01 2017   0.0  22.08 2017-01-03      1
# 3  04 01 2017   0.0   2.55 2017-01-04      1
# 4  05 01 2017   0.0   5.10 2017-01-05      1

# %%
ax = sns.boxplot(x="month", y="CAPE", data=df)
plt.show()

# %%
ax = sns.boxplot(x="month", y="CAPE", data=df1)
plt.show()

# %%
ax = sns.boxplot(x="month", y="PW", data=df)
plt.show()

# %%
ax = sns.boxplot(x="month", y="PW", data=df1)
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df1, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df)
plt.show(g)

# %%
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df1)
plt.show(g)
