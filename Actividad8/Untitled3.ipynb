# %%
from scipy.integrate import odeint 
from scipy import array, arange,pi, sin
import matplotlib.pyplot as plt

def VanDerPol(X,t):
    x = X[0]
    y = X[1]
    a = X[0]
    b = X[1]
    c = X[0]
    d = X[1]
    e = X[0]
    f = X[1]
    g = X[0]
    h = X[1]
    j = X[0]
    k = X[1]
    l = X[0]
    n = X[1]
    o = X[0]
    p = X[1]
    q = X[0]
    r = X[1]
    s = X[0]
    v = X[1]
    dx = y
    dy = u*(1 - x*x)*dx - x
    return array([dx, dy])

t0 = 0
tmax = 30
pastemps = 0.01
t = arange(t0, tmax, pastemps)

#Condiciones iniciales
x0 = 2.0
y0 = 0.0

#Mu
u = 3.0

#Solución a la ecuación diferencial
x, y = odeint(VanDerPol,(x0,y0),t).T

#Trayectoria del ocilador
p1 = plt.figure(figsize=(15,3))
plt.grid()
plt.xlabel('$t$', fontsize = 20)
plt.ylabel('$x$', fontsize = 20)
plt.plot(t, x)
plt.show()

p1.savefig('TerceraFig.png')

# %%
t0 = 0
tmax = 30
pastemps = 0.01
t = arange(t0, tmax, pastemps)

#Mu
u = 0.01

#Solución a la ecuación diferencial
a, b = odeint(VanDerPol,(x0,y0),t).T

u = 0.1

#Solución a la ecuación diferencial
c, d = odeint(VanDerPol,(x0,y0),t).T

u = 0.5

#Solución a la ecuación diferencial
e, f = odeint(VanDerPol,(x0,y0),t).T

u = 1.0

#Solución a la ecuación diferencial
g, h = odeint(VanDerPol,(x0,y0),t).T

u = 1.5

#Solución a la ecuación diferencial
j, k = odeint(VanDerPol,(x0,y0),t).T

u = 2.0

#Solución a la ecuación diferencial
l, n = odeint(VanDerPol,(x0,y0),t).T

u = 2.5

#Solución a la ecuación diferencial
o, p = odeint(VanDerPol,(x0,y0),t).T

u = 3.0

#Solución a la ecuación diferencial
q, r = odeint(VanDerPol,(x0,y0),t).T

u = 3.5

#Solución a la ecuación diferencial
s, v = odeint(VanDerPol,(x0,y0),t).T

u = 4.0

#Solución a la ecuación diferencial
x, y = odeint(VanDerPol,(x0,y0),t).T

#Trayectoria de fase
p2 = plt.figure(figsize=(4,9))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(a, b)
plt.plot(c, d)
plt.plot(e, f)
plt.plot(g, h)
plt.plot(j, k)
plt.plot(l, n)
plt.plot(o, p)
plt.plot(q, r)
plt.plot(s, v)
plt.plot(x, y)
#plt.xlim(-2.5,2.5)
#plt.ylim(-6.0,6.0)
plt.show()

p2.savefig('SegundaFig.png')

# %%
t0 = 0
tmax = 40
pastemps = 0.01
t = arange(t0, tmax, pastemps)

#Mu
u = 3.0

#Condiciones iniciales
x0 = -5.0
y0 = -5.0

#Solución a la ecuación diferencial
a, b = odeint(VanDerPol,(x0,y0),t).T

x1 = 4.0
y1 = -2.0

#Solución a la ecuación diferencial
c, d = odeint(VanDerPol,(x1,y1),t).T

x2 = -1.0
y2 = 4.0

#Solución a la ecuación diferencial
e, f = odeint(VanDerPol,(x2,y2),t).T

x3 = 0.1
y3 = 0.1

#Solución a la ecuación diferencial
g, h = odeint(VanDerPol,(x3,y3),t).T

x4 = 2.0
y4 = 0.0

#Solución a la ecuación diferencial
x, y = odeint(VanDerPol,(x4,y4),t).T

p3 = plt.figure(figsize=(7,4))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(a, b, 'b')
plt.xlim(-6.0,6.0)
plt.ylim(-6.0,6.0)
plt.show()

p4 = plt.figure(figsize=(7,4))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(c, d, 'b')
plt.xlim(-6.0,6.0)
plt.ylim(-6.0,6.0)
plt.show()

p5 = plt.figure(figsize=(7,4))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(e, f, 'b')
plt.xlim(-6.0,6.0)
plt.ylim(-6.0,8.0)
plt.show()

p6 = plt.figure(figsize=(7,4))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(g, h, 'b')
plt.xlim(-6.0,6.0)
plt.ylim(-6.0,6.0)
plt.show()

p7 = plt.figure(figsize=(7,4))
plt.grid()
plt.xlabel('$x$', fontsize = 20)
plt.ylabel('$y$', fontsize = 20)
plt.plot(x, y, 'r')
plt.xlim(-6.0,6.0)
plt.ylim(-6.0,6.0)
plt.show()

p3.savefig('EspacioFase1.png')
p4.savefig('EspacioFase2.png')
p5.savefig('EspacioFase3.png')
p6.savefig('EspacioFase4.png')
p7.savefig('EspacioFase.png')

# %%
import numpy as np

def VanDerPol(X,t):
    x = X[0]
    y = X[1]
    dx = y
    dy = u*(1 - x*x)*dx - x + M*np.sin(w*t)
    return array([dx, dy])

t0 = 0
tmax = 160
pastemps = 0.01
t = arange(t0, tmax, pastemps)

#Condiciones iniciales
x0 = 2.0
y0 = 0.0

#Parametros
u = 8.53
M = 1.2
w = np.pi/5.0

#Solución a la ecuación diferencial
x, y = odeint(VanDerPol,(x0,y0),t).T

#Trayectoria del ocilador
p1 = plt.figure(figsize=(20,3.0))
plt.grid()
plt.xlabel('$t$', fontsize = 20)
plt.ylabel('$x$', fontsize = 20)
plt.plot(t, x)
plt.show()

p1.savefig('CuartaFig.png')
